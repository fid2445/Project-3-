# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import json

# %%
with open('C:/Users/fid24/.secret/tmdb_api.json', 'r') as f:
    login = json.load(f)
## Display the keys of the loaded dict
login.keys()
# Out:
# dict_keys(['api-key-tmdb'])

# %%
import tmdbsimple as tmdb
tmdb.API_KEY =  login['api-key-tmdb']

# %%
JSON_FILE_2000 = f"C:/Users/fid24/OneDrive/Documents/Github/Project-3-/data/final_tmdb_data_2000.csv.gz"
JSON_FILE_2000
# Out:
# 'C:/Users/fid24/OneDrive/Documents/Github/Project-3-/data/final_tmdb_data_2000.csv.gz'

# %%
df_2000 = pd.read_csv(JSON_FILE_2000)
df_2000 = df_2000.drop(df_2000.index[[0]])
df_2000.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0116748    0.0                               NaN                   NaN
# 5  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
#
#        budget                                             genres  \
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 2         0.0           [{'id': 878, 'name': 'Science Fiction'}]
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 4         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 5    150000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
#
#                                homepage        id original_language  \
# 1                                   NaN   62127.0                en
# 2                                   NaN  110977.0                en
# 3                                   NaN  442869.0                hi
# 4                                   NaN  579396.0                hi
# 5  http://www.wkw-inthemoodforlove.com/     843.0                cn
#
#     original_title  ...     revenue  runtime  \
# 1  The Fantasticks  ...         0.0     86.0
# 2    For the Cause  ...         0.0    100.0
# 3             Gang  ...         0.0    152.0
# 4         Karobaar  ...         0.0    180.0
# 5             花樣年華  ...  12854953.0     99.0
#
#                                     spoken_languages    status  \
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 4  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 5  [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
#
#                                              tagline                 title  \
# 1      Try to remember the first time magic happened       The Fantasticks
# 2       The ultimate showdown on a forbidden planet.         For the Cause
# 3                                                NaN                  Gang
# 4                               The Business of Love              Karobaar
# 5  Feel the heat, keep the feeling burning, let t...  In the Mood for Love
#
#    video  vote_average vote_count certification
# 1    0.0           5.5       22.0           NaN
# 2    0.0           5.1        8.0           NaN
# 3    0.0           0.0        0.0           NaN
# 4    0.0           5.5        2.0           NaN
# 5    0.0           8.1     1950.0            PG
#
# [5 rows x 26 columns]

# %%
JSON_FILE_2001 = f"C:/Users/fid24/OneDrive/Documents/Github/Project-3-/data/final_tmdb_data_2001.csv.gz"
JSON_FILE_2001
# Out:
# 'C:/Users/fid24/OneDrive/Documents/Github/Project-3-/data/final_tmdb_data_2001.csv.gz'

# %%
df_2001 = pd.read_csv(JSON_FILE_2001)
df_2001 = df_2001.drop(df_2001.index[[0]])
df_2001.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 1  tt0035423    0.0  /ab5yL8zgRotrICzGbEl10z24N71.jpg                   NaN
# 2  tt0079644    0.0  /79axmuH1UGkB7m72jjB9rPff9om.jpg                   NaN
# 3  tt0089067    0.0                               NaN                   NaN
# 4  tt0114447    0.0                               NaN                   NaN
# 5  tt0114722    0.0                               NaN                   NaN
#
#        budget                                             genres homepage  \
# 1  48000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 14, 'nam...      NaN
# 2         0.0                     [{'id': 10752, 'name': 'War'}]      NaN
# 3         0.0                     [{'id': 35, 'name': 'Comedy'}]      NaN
# 4         0.0  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...      NaN
# 5         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...      NaN
#
#          id original_language             original_title  ...     revenue  \
# 1   11232.0                en             Kate & Leopold  ...  76019048.0
# 2  285529.0                id              November 1828  ...         0.0
# 3  210258.0                es  El día de los albañiles 2  ...         0.0
# 4  151007.0                en           The Silent Force  ...         0.0
# 5  276251.0                es                   3 Noches  ...         0.0
#
#    runtime                                   spoken_languages    status  \
# 1    118.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2    140.0  [{'english_name': 'Indonesian', 'iso_639_1': '...  Released
# 3     90.0  [{'english_name': 'Spanish', 'iso_639_1': 'es'...  Released
# 4     90.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 5    105.0  [{'english_name': 'Spanish', 'iso_639_1': 'es'...  Released
#
#                                              tagline  \
# 1  If they lived in the same century they'd be pe...
# 2                                                NaN
# 3     The laborers are back full of love and laughs.
# 4  They left him for dead... They should have fin...
# 5                                                NaN
#
#                        title  video  vote_average vote_count certification
# 1             Kate & Leopold    0.0           6.3     1137.0         PG-13
# 2              November 1828    0.0           0.0        0.0           NaN
# 3  El día de los albañiles 2    0.0           7.2       71.0           NaN
# 4           The Silent Force    0.0           5.0        3.0           NaN
# 5                   3 Nights    0.0           0.0        0.0           NaN
#
# [5 rows x 26 columns]

# %%
df = pd.concat([df_2000, df_2001], ignore_index=True)
df
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0     tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 1     tt0113092    0.0                               NaN
# 2     tt0116391    0.0                               NaN
# 3     tt0116748    0.0                               NaN
# 4     tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# ...         ...    ...                               ...
# 4435  tt9071078    0.0                               NaN
# 4436  tt9099724    0.0                               NaN
# 4437  tt9798698    0.0                               NaN
# 4438  tt0286560    0.0  /l2NTN8FJq0jTLSMSjEekL4nvfTj.jpg
# 4439  tt0304866    0.0                               NaN
#
#      belongs_to_collection      budget  \
# 0                      NaN  10000000.0
# 1                      NaN         0.0
# 2                      NaN         0.0
# 3                      NaN         0.0
# 4                      NaN    150000.0
# ...                    ...         ...
# 4435                   NaN         0.0
# 4436                   NaN         0.0
# 4437                   NaN         0.0
# 4438                   NaN         0.0
# 4439                   NaN         0.0
#
#                                                  genres  \
# 0     [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 1              [{'id': 878, 'name': 'Science Fiction'}]
# 2     [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 3     [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 4     [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# ...                                                 ...
# 4435                     [{'id': 28, 'name': 'Action'}]
# 4436                      [{'id': 18, 'name': 'Drama'}]
# 4437                                                 []
# 4438  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4439  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
#
#                                              homepage        id  \
# 0                                                 NaN   62127.0
# 1                                                 NaN  110977.0
# 2                                                 NaN  442869.0
# 3                                                 NaN  579396.0
# 4                http://www.wkw-inthemoodforlove.com/     843.0
# ...                                               ...       ...
# 4435  http://www.hkcinemagic.com/en/movie.asp?id=6627  201706.0
# 4436                                              NaN  616033.0
# 4437                                              NaN  580269.0
# 4438                                              NaN  240270.0
# 4439                                              NaN  407637.0
#
#      original_language             original_title  ...     revenue  runtime  \
# 0                   en            The Fantasticks  ...         0.0     86.0
# 1                   en              For the Cause  ...         0.0    100.0
# 2                   hi                       Gang  ...         0.0    152.0
# 3                   hi                   Karobaar  ...         0.0    180.0
# 4                   cn                       花樣年華  ...  12854953.0     99.0
# ...                ...                        ...  ...         ...      ...
# 4435                cn                       致命密函  ...         0.0     90.0
# 4436                ja  Rokushukan Private Moment  ...         0.0    102.0
# 4437                en              Gay holocaust  ...         0.0      0.0
# 4438                pt                 Copacabana  ...         0.0     90.0
# 4439                cn                       火武耀扬  ...         0.0    105.0
#
#                                        spoken_languages    status  \
# 0     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2     [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 3     [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 4     [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# ...                                                 ...       ...
# 4435  [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# 4436  [{'english_name': 'Japanese', 'iso_639_1': 'ja...  Released
# 4437                                                 []  Released
# 4438  [{'english_name': 'Portuguese', 'iso_639_1': '...  Released
# 4439  [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
#
#                                                 tagline  \
# 0         Try to remember the first time magic happened
# 1          The ultimate showdown on a forbidden planet.
# 2                                                   NaN
# 3                                  The Business of Love
# 4     Feel the heat, keep the feeling burning, let t...
# ...                                                 ...
# 4435                                                NaN
# 4436                                                NaN
# 4437                                                NaN
# 4438                                                NaN
# 4439                                                NaN
#
#                           title  video  vote_average vote_count certification
# 0               The Fantasticks    0.0           5.5       22.0           NaN
# 1                 For the Cause    0.0           5.1        8.0           NaN
# 2                          Gang    0.0           0.0        0.0           NaN
# 3                      Karobaar    0.0           5.5        2.0           NaN
# 4          In the Mood for Love    0.0           8.1     1950.0            PG
# ...                         ...    ...           ...        ...           ...
# 4435             Chinese Heroes    0.0           3.0        2.0           NaN
# 4436  Rokushukan Private Moment    0.0           0.0        0.0           NaN
# 4437              Gay holocaust    0.0           0.0        0.0           NaN
# 4438                 Copacabana    0.0           8.3        3.0           NaN
# 4439                Unbeatables    0.0           0.0        0.0           NaN
#
# [4440 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4440 entries, 0 to 4439
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                4440 non-null   object
#  1   adult                  4440 non-null   float64
#  2   backdrop_path          1908 non-null   object
#  3   belongs_to_collection  248 non-null    object
#  4   budget                 4440 non-null   float64
#  5   genres                 4440 non-null   object
#  6   homepage               229 non-null    object
#  7   id                     4440 non-null   float64
#  8   original_language      4440 non-null   object
#  9   original_title         4440 non-null   object
#  10  overview               4072 non-null   object
#  11  popularity             4440 non-null   float64
#  12  poster_path            3725 non-null   object
#  13  production_companies   4440 non-null   object
#  14  production_countries   4440 non-null   object
#  15  release_date           4397 non-null   object
#  16  revenue                4440 non-null   float64
#  17  runtime                4440 non-null   float64
#  18  spoken_languages       4440 non-null   object
#  19  status                 4440 non-null   object
#  20  tagline                1228 non-null   object
#  21  title                  4440 non-null   object
#  22  video                  4440 non-null   float64
#  23  vote_average           4440 non-null   float64
#  24  vote_count             4440 non-null   float64
#  25  certification          816 non-null    object
# dtypes: float64(9), object(17)
# memory usage: 902.0+ KB

# %%
df.to_csv("Data/df_2000_2001.csv.gz",compression='gzip',index=False)

# %%
#drop columns to get the data you want and resave the csv

# %%
df.drop(columns='adult', inplace=True)
df.drop(columns='backdrop_path', inplace=True)
df.drop(columns='belongs_to_collection', inplace=True)
df.drop(columns='genres', inplace=True)
df.drop(columns='homepage', inplace=True)
df.drop(columns='id', inplace=True)
df.drop(columns='original_language', inplace=True)
df.drop(columns='overview', inplace=True)
df.drop(columns='popularity', inplace=True)
df.drop(columns='poster_path', inplace=True)
df.drop(columns='production_companies', inplace=True)
df.drop(columns='production_countries', inplace=True)
df.drop(columns='release_date', inplace=True)
df.drop(columns='runtime', inplace=True)
df.drop(columns='spoken_languages', inplace=True)
df.drop(columns='status', inplace=True)
df.drop(columns='tagline', inplace=True)
df.drop(columns='video', inplace=True)
df.drop(columns='vote_average', inplace=True)
df.drop(columns='vote_count', inplace=True)
df.drop(columns='original_title', inplace=True)
df
# Out:
#         imdb_id      budget     revenue                      title  \
# 0     tt0113026  10000000.0         0.0            The Fantasticks
# 1     tt0113092         0.0         0.0              For the Cause
# 2     tt0116391         0.0         0.0                       Gang
# 3     tt0116748         0.0         0.0                   Karobaar
# 4     tt0118694    150000.0  12854953.0       In the Mood for Love
# ...         ...         ...         ...                        ...
# 4435  tt9071078         0.0         0.0             Chinese Heroes
# 4436  tt9099724         0.0         0.0  Rokushukan Private Moment
# 4437  tt9798698         0.0         0.0              Gay holocaust
# 4438  tt0286560         0.0         0.0                 Copacabana
# 4439  tt0304866         0.0         0.0                Unbeatables
#
#      certification
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4               PG
# ...            ...
# 4435           NaN
# 4436           NaN
# 4437           NaN
# 4438           NaN
# 4439           NaN
#
# [4440 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4440 entries, 0 to 4439
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   imdb_id        4440 non-null   object
#  1   budget         4440 non-null   float64
#  2   revenue        4440 non-null   float64
#  3   title          4440 non-null   object
#  4   certification  816 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 173.6+ KB

# %%
df.to_csv("Data/df_2000_2001_budget_revenue_title_cert.csv.gz",compression='gzip',index=False)

# %%
df = pd.read_csv('C:/Users/fid24/OneDrive/Documents/Github/Project-3-/data/df_2000_2001_budget_revenue_title_cert.csv.gz')
df.head()
# Out:
#      imdb_id      budget     revenue                 title certification
# 0  tt0113026  10000000.0         0.0       The Fantasticks           NaN
# 1  tt0113092         0.0         0.0         For the Cause           NaN
# 2  tt0116391         0.0         0.0                  Gang           NaN
# 3  tt0116748         0.0         0.0              Karobaar           NaN
# 4  tt0118694    150000.0  12854953.0  In the Mood for Love            PG

# %%
df.duplicated().sum()
# Out:
# 0

# %%
filter_ = (df['budget']>0) | (df['revenue']>0)

# %%
plot_df = df[filter_]

# %%
sns.barplot(data=plot_df);

# %%
plot_df
# Out:
#         imdb_id      budget     revenue                        title  \
# 0     tt0113026  10000000.0         0.0              The Fantasticks
# 4     tt0118694    150000.0  12854953.0         In the Mood for Love
# 6     tt0119273  15000000.0         0.0             Heavy Metal 2000
# 12    tt0120263         0.0     80334.0  Songs from the Second Floor
# 13    tt0120467    120000.0     14904.0                       Vulgar
# ...         ...         ...         ...                          ...
# 4339  tt1400341    114263.0         0.0                Instant Karma
# 4362  tt1764172    250000.0         0.0                Among Thieves
# 4391  tt2957918      2000.0         0.0                      Toaster
# 4411  tt4366046        11.0         0.0         Mi crimen al desnudo
# 4416  tt5043264     50000.0         0.0                   Barricades
#
#      certification
# 0              NaN
# 4               PG
# 6                R
# 12             NaN
# 13               R
# ...            ...
# 4339           NaN
# 4362           NaN
# 4391           NaN
# 4411           NaN
# 4416           NaN
#
# [716 rows x 5 columns]

# %% [markdown]
# 716 movies have either a listed budget or revenue > 0.

# %%
cert_count = plot_df['certification'].value_counts()
cert_count
# Out:
# R        229
# PG-13    131
# PG        35
# NR        17
# G         15
# NC-17      1
# Name: certification, dtype: int64

# %%
cert_list = ['R','PG','PG-13','G']
cert_filter = plot_df['certification'].isin(cert_list)

# %%
cert_df = plot_df.loc[cert_filter]

# %%
cert_df['certification'].value_counts()
# Out:
# R        229
# PG-13    131
# PG        35
# G         15
# Name: certification, dtype: int64

# %% [markdown]
# We have 229 rated R movies, 131 PG-13, 35 PG and 15 rated G with either a budget or revenue > 0.

# %%
sns.countplot(data=cert_df, x='certification');

# %%
sns.barplot(data=cert_df, x='certification', y= 'budget');

# %%
budget_filter = (df['budget']>0)

# %%
budget_df = df[budget_filter]

# %%
budget_df
# Out:
#         imdb_id      budget     revenue                 title certification
# 0     tt0113026  10000000.0         0.0       The Fantasticks           NaN
# 4     tt0118694    150000.0  12854953.0  In the Mood for Love            PG
# 6     tt0119273  15000000.0         0.0      Heavy Metal 2000             R
# 13    tt0120467    120000.0     14904.0                Vulgar             R
# 15    tt0120626   6105121.0         0.0     Captains of April           NaN
# ...         ...         ...         ...                   ...           ...
# 4339  tt1400341    114263.0         0.0         Instant Karma           NaN
# 4362  tt1764172    250000.0         0.0         Among Thieves           NaN
# 4391  tt2957918      2000.0         0.0               Toaster           NaN
# 4411  tt4366046        11.0         0.0  Mi crimen al desnudo           NaN
# 4416  tt5043264     50000.0         0.0            Barricades           NaN
#
# [600 rows x 5 columns]

# %%
budget_df.groupby('certification')['budget'].mean().round()
# Out:
# certification
# G        40953834.0
# NR        9736372.0
# PG       47704546.0
# PG-13    45227263.0
# R        22479746.0
# Name: budget, dtype: float64

# %% [markdown]
# The average budget for movies rated G is 40,953,834.

# %% [markdown]
# The average budget for movies rated PG is 47,704,546.

# %% [markdown]
# The average budget for movies rated PG-13 is 45,227,263.

# %% [markdown]
# The average budget for movies rated G is 22,479,746.

# %%
sns.barplot(data=cert_df, x='certification', y= 'revenue');

# %%
revenue_filter = (df['revenue']>0)

# %%
revenue_df = df[revenue_filter]

# %%
revenue_df
# Out:
#         imdb_id      budget      revenue                        title  \
# 4     tt0118694    150000.0   12854953.0         In the Mood for Love
# 12    tt0120263         0.0      80334.0  Songs from the Second Floor
# 13    tt0120467    120000.0      14904.0                       Vulgar
# 16    tt0120630  45000000.0  224834564.0                  Chicken Run
# 19    tt0120753   8000000.0     105983.0     The Million Dollar Hotel
# ...         ...         ...          ...                          ...
# 4091  tt0332021         0.0   10339700.0                    Love Trip
# 4259  tt0445841  12500000.0  123021750.0            A Gambler's Story
# 4263  tt0449832         0.0     281517.0               Bana Şans Dile
# 4296  tt0807944    500000.0     500000.0                       Dheena
# 4311  tt1039952    500000.0     500000.0                      Citizen
#
#      certification
# 4               PG
# 12             NaN
# 13               R
# 16               G
# 19               R
# ...            ...
# 4091           NaN
# 4259           NaN
# 4263           NaN
# 4296           NaN
# 4311           NaN
#
# [485 rows x 5 columns]

# %%
revenue_df.groupby('certification')['budget'].mean().round()
# Out:
# certification
# G        40857143.0
# NC-17           0.0
# NR        7391667.0
# PG       50274194.0
# PG-13    44523556.0
# R        23426853.0
# Name: budget, dtype: float64

# %% [markdown]
# The average revenue for movies rated G is 40,857,143.

# %% [markdown]
# The average revenue for movies rated PG is 50,274,194.

# %% [markdown]
# The average revenue for movies rated PG-13 is 44,523,556.

# %% [markdown]
# The average revenue for movies rated R is 23,426,853.

# %%
df.to_csv("Data/tmdb_results_combined.csv.gz",compression='gzip',index=False)

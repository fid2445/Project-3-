# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm_notebook
FOLDER = "Data/"
os.makedirs(FOLDER, exist_ok=True)
os.listdir(FOLDER)
# Out:
# ['df_2000_2001.csv.gz',
#  'df_2000_2001_budget_revenue_title_cert.csv.gz',
#  'df_2002-2014_no_2007.csv.gz',
#  'df_clean_basics.csv.gz',
#  'final_basics_df.csv.gz',
#  'final_tmdb_data_2000.csv.gz',
#  'final_tmdb_data_2001.csv.gz',
#  'final_tmdb_data_2002.csv.gz',
#  'final_tmdb_data_2003.csv.gz',
#  'final_tmdb_data_2004.csv.gz',
#  'final_tmdb_data_2005.csv.gz',
#  'final_tmdb_data_2006.csv.gz',
#  'final_tmdb_data_2008.csv.gz',
#  'final_tmdb_data_2009.csv.gz',
#  'final_tmdb_data_2010.csv.gz',
#  'final_tmdb_data_2011.csv.gz',
#  'final_tmdb_data_2012.csv.gz',
#  'final_tmdb_data_2013.csv.gz',
#  'final_tmdb_data_2014.csv.gz',
#  'title_akas.csv.gz',
#  'title_basics.csv.gz',
#  'title_ratings.csv.gz',
#  'tmdb_api_results_2000.json',
#  'tmdb_api_results_2001.json',
#  'tmdb_api_results_2002.json',
#  'tmdb_api_results_2003.json',
#  'tmdb_api_results_2004.json',
#  'tmdb_api_results_2005.json',
#  'tmdb_api_results_2006.json',
#  'tmdb_api_results_2007.json',
#  'tmdb_api_results_2008.json',
#  'tmdb_api_results_2009.json',
#  'tmdb_api_results_2010.json',
#  'tmdb_api_results_2011.json',
#  'tmdb_api_results_2012.json',
#  'tmdb_api_results_2013.json',
#  'tmdb_api_results_2014.json',
#  'tmdb_api_results_2015.json',
#  'tmdb_api_results_2016.json',
#  'tmdb_api_results_2017.json',
#  'tmdb_results_combined.csv.gz']

# %%
import pymysql
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine
from sqlalchemy_utils import create_database, database_exists
# Create connection string using credentials following this format
# connection = "dialect+driver://username:password@host:port/database"
connection = "mysql+pymysql://root:root@localhost/movies"
engine = create_engine(connection)

# %%
if database_exists(connection) == False: create_database(connection)
else: print('The database already exists.')
# Out:
# The database already exists.

# %%
basics = pd.read_csv('Data/title_basics.csv.gz', low_memory=False)
basics
# Out:
#            tconst titleType  \
# 0       tt0035423     movie
# 1       tt0062336     movie
# 2       tt0069049     movie
# 3       tt0079644     movie
# 4       tt0088751     movie
# ...           ...       ...
# 136203  tt9916170     movie
# 136204  tt9916190     movie
# 136205  tt9916270     movie
# 136206  tt9916362     movie
# 136207  tt9916538     movie
#
#                                              primaryTitle  \
# 0                                          Kate & Leopold
# 1       The Tango of the Widower and Its Distorting Mi...
# 2                              The Other Side of the Wind
# 3                                           November 1828
# 4                                       The Naked Monster
# ...                                                   ...
# 136203                                      The Rehearsal
# 136204                                          Safeguard
# 136205                           Il talento del calabrone
# 136206                                              Coven
# 136207                                Kuambil Lagi Hatiku
#
#                                     originalTitle  isAdult  startYear  \
# 0                                  Kate & Leopold        0       2001
# 1       El Tango del Viudo y Su Espejo Deformante        0       2020
# 2                      The Other Side of the Wind        0       2018
# 3                                   November 1828        0       2001
# 4                               The Naked Monster        0       2005
# ...                                           ...      ...        ...
# 136203                                   O Ensaio        0       2019
# 136204                                  Safeguard        0       2020
# 136205                   Il talento del calabrone        0       2020
# 136206                                   Akelarre        0       2020
# 136207                        Kuambil Lagi Hatiku        0       2019
#
#         endYear  runtimeMinutes                     genres
# 0           NaN             118     Comedy,Fantasy,Romance
# 1           NaN              70                      Drama
# 2           NaN             122                      Drama
# 3           NaN             140                  Drama,War
# 4           NaN             100       Comedy,Horror,Sci-Fi
# ...         ...             ...                        ...
# 136203      NaN              51                      Drama
# 136204      NaN              95  Action,Adventure,Thriller
# 136205      NaN              84                   Thriller
# 136206      NaN              92              Drama,History
# 136207      NaN             123                      Drama
#
# [136208 rows x 9 columns]

# %%
basics = basics.replace({'\\N':np.nan})
basics.dropna(subset=['genres'], inplace=True)

# %%
## create a col with a list of genres
basics['genres_split'] = basics['genres'].str.split(',')
basics
# Out:
#            tconst titleType  \
# 0       tt0035423     movie
# 1       tt0062336     movie
# 2       tt0069049     movie
# 3       tt0079644     movie
# 4       tt0088751     movie
# ...           ...       ...
# 136203  tt9916170     movie
# 136204  tt9916190     movie
# 136205  tt9916270     movie
# 136206  tt9916362     movie
# 136207  tt9916538     movie
#
#                                              primaryTitle  \
# 0                                          Kate & Leopold
# 1       The Tango of the Widower and Its Distorting Mi...
# 2                              The Other Side of the Wind
# 3                                           November 1828
# 4                                       The Naked Monster
# ...                                                   ...
# 136203                                      The Rehearsal
# 136204                                          Safeguard
# 136205                           Il talento del calabrone
# 136206                                              Coven
# 136207                                Kuambil Lagi Hatiku
#
#                                     originalTitle  isAdult  startYear  \
# 0                                  Kate & Leopold        0       2001
# 1       El Tango del Viudo y Su Espejo Deformante        0       2020
# 2                      The Other Side of the Wind        0       2018
# 3                                   November 1828        0       2001
# 4                               The Naked Monster        0       2005
# ...                                           ...      ...        ...
# 136203                                   O Ensaio        0       2019
# 136204                                  Safeguard        0       2020
# 136205                   Il talento del calabrone        0       2020
# 136206                                   Akelarre        0       2020
# 136207                        Kuambil Lagi Hatiku        0       2019
#
#         endYear  runtimeMinutes                     genres  \
# 0           NaN             118     Comedy,Fantasy,Romance
# 1           NaN              70                      Drama
# 2           NaN             122                      Drama
# 3           NaN             140                  Drama,War
# 4           NaN             100       Comedy,Horror,Sci-Fi
# ...         ...             ...                        ...
# 136203      NaN              51                      Drama
# 136204      NaN              95  Action,Adventure,Thriller
# 136205      NaN              84                   Thriller
# 136206      NaN              92              Drama,History
# 136207      NaN             123                      Drama
#
#                          genres_split
# 0          [Comedy, Fantasy, Romance]
# 1                             [Drama]
# 2                             [Drama]
# 3                        [Drama, War]
# 4            [Comedy, Horror, Sci-Fi]
# ...                               ...
# 136203                        [Drama]
# 136204  [Action, Adventure, Thriller]
# 136205                     [Thriller]
# 136206               [Drama, History]
# 136207                        [Drama]
#
# [136208 rows x 10 columns]

# %%
exploded_genres = basics.explode('genres_split')
exploded_genres
# Out:
#            tconst titleType  \
# 0       tt0035423     movie
# 0       tt0035423     movie
# 0       tt0035423     movie
# 1       tt0062336     movie
# 2       tt0069049     movie
# ...           ...       ...
# 136204  tt9916190     movie
# 136205  tt9916270     movie
# 136206  tt9916362     movie
# 136206  tt9916362     movie
# 136207  tt9916538     movie
#
#                                              primaryTitle  \
# 0                                          Kate & Leopold
# 0                                          Kate & Leopold
# 0                                          Kate & Leopold
# 1       The Tango of the Widower and Its Distorting Mi...
# 2                              The Other Side of the Wind
# ...                                                   ...
# 136204                                          Safeguard
# 136205                           Il talento del calabrone
# 136206                                              Coven
# 136206                                              Coven
# 136207                                Kuambil Lagi Hatiku
#
#                                     originalTitle  isAdult  startYear  \
# 0                                  Kate & Leopold        0       2001
# 0                                  Kate & Leopold        0       2001
# 0                                  Kate & Leopold        0       2001
# 1       El Tango del Viudo y Su Espejo Deformante        0       2020
# 2                      The Other Side of the Wind        0       2018
# ...                                           ...      ...        ...
# 136204                                  Safeguard        0       2020
# 136205                   Il talento del calabrone        0       2020
# 136206                                   Akelarre        0       2020
# 136206                                   Akelarre        0       2020
# 136207                        Kuambil Lagi Hatiku        0       2019
#
#         endYear  runtimeMinutes                     genres genres_split
# 0           NaN             118     Comedy,Fantasy,Romance       Comedy
# 0           NaN             118     Comedy,Fantasy,Romance      Fantasy
# 0           NaN             118     Comedy,Fantasy,Romance      Romance
# 1           NaN              70                      Drama        Drama
# 2           NaN             122                      Drama        Drama
# ...         ...             ...                        ...          ...
# 136204      NaN              95  Action,Adventure,Thriller     Thriller
# 136205      NaN              84                   Thriller     Thriller
# 136206      NaN              92              Drama,History        Drama
# 136206      NaN              92              Drama,History      History
# 136207      NaN             123                      Drama        Drama
#
# [236817 rows x 10 columns]

# %%
unique_genres = basics['genres_split'].explode().unique()
unique_genres
# Out:
# array(['Comedy', 'Fantasy', 'Romance', 'Drama', 'War', 'Horror', 'Sci-Fi',
#        'Mystery', 'Adventure', 'Musical', 'Action', 'Crime', 'Thriller',
#        'Music', 'Animation', 'Family', 'History', 'Biography', 'Sport',
#        'Western', 'Adult', 'Short', 'Reality-TV', 'News', 'Talk-Show',
#        'Game-Show'], dtype=object)

# %%
unique_genres = sorted(exploded_genres['genres_split'].unique())

# %%
title_genres = exploded_genres[['tconst', 'genres_split']].copy()
title_genres.head()
# Out:
#       tconst genres_split
# 0  tt0035423       Comedy
# 0  tt0035423      Fantasy
# 0  tt0035423      Romance
# 1  tt0062336        Drama
# 2  tt0069049        Drama

# %%
genre_ints = range(len(unique_genres))
genre_map = dict(zip(unique_genres, genre_ints))
genre_map
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Drama': 7,
#  'Family': 8,
#  'Fantasy': 9,
#  'Game-Show': 10,
#  'History': 11,
#  'Horror': 12,
#  'Music': 13,
#  'Musical': 14,
#  'Mystery': 15,
#  'News': 16,
#  'Reality-TV': 17,
#  'Romance': 18,
#  'Sci-Fi': 19,
#  'Short': 20,
#  'Sport': 21,
#  'Talk-Show': 22,
#  'Thriller': 23,
#  'War': 24,
#  'Western': 25}

# %%
## make new integer genre_id and drop string genres
basics['genre_id'] = basics['genres_split'].replace(genre_map)
basics = basics.drop(columns='genres_split')

# %%
genre_lookup = pd.DataFrame({'Genre_Name': genre_map.keys(), 'Genre_ID': genre_map.values()})
genre_lookup.head()
# Out:
#   Genre_Name  Genre_ID
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
# 3  Animation         3
# 4  Biography         4

# %%
genre_lookup.to_sql('genres', engine, if_exists='replace',index=False)
# Out:
# 26

# %%
q = """SELECT * FROM genres LIMIT 5;"""
pd.read_sql(q, engine)
# Out:
#   Genre_Name  Genre_ID
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
# 3  Animation         3
# 4  Biography         4

# %%
title_genres.head()
# Out:
#       tconst genres_split
# 0  tt0035423       Comedy
# 0  tt0035423      Fantasy
# 0  tt0035423      Romance
# 1  tt0062336        Drama
# 2  tt0069049        Drama

# %%
title_genres = pd.DataFrame({'tconst': basics['tconst'], 'Genre_ID': genre_lookup['Genre_ID']}) # had the wrong df here? 
title_genres.head()
# Out:
#       tconst  Genre_ID
# 0  tt0035423       0.0
# 1  tt0062336       1.0
# 2  tt0069049       2.0
# 3  tt0079644       3.0
# 4  tt0088751       4.0

# %%
title_genres.dtypes
# Out:
# tconst       object
# Genre_ID    float64
# dtype: object

# %%
from sqlalchemy.types import *
## Calculate max string lengths for object columns
key_len = basics['tconst'].fillna('').map(len).max()

# %%
## Create a schema dictonary using Sqlalchemy datatype objects
df_schema = {
    "tconst": String(key_len+1), 
    "Genre_ID": Integer()}

# %%
title_genres
# Out:
#            tconst  Genre_ID
# 0       tt0035423       0.0
# 1       tt0062336       1.0
# 2       tt0069049       2.0
# 3       tt0079644       3.0
# 4       tt0088751       4.0
# ...           ...       ...
# 136203  tt9916170       NaN
# 136204  tt9916190       NaN
# 136205  tt9916270       NaN
# 136206  tt9916362       NaN
# 136207  tt9916538       NaN
#
# [136208 rows x 2 columns]

# %%
title_genres.to_sql('title_genres', engine, index=False, if_exists='replace', dtype=df_schema)
# Out:
# 136208

# %%
engine.execute('ALTER TABLE title_genres ADD PRIMARY KEY (`tconst`);')

# %%
q = """SELECT * FROM title_genres LIMIT 5;"""
pd.read_sql(q, engine)
# Out:
#       tconst  Genre_ID
# 0  tt0035423         0
# 1  tt0062336         1
# 2  tt0069049         2
# 3  tt0079644         3
# 4  tt0088751         4

# %%
basics.dtypes
# Out:
# tconst             object
# titleType          object
# primaryTitle       object
# originalTitle      object
# isAdult             int64
# startYear           int64
# endYear           float64
# runtimeMinutes      int64
# genres             object
# genre_id           object
# dtype: object

# %%
basics = basics.drop(columns = ['titleType', 'originalTitle', 'isAdult', 'genres', 'genre_id'])

# %%
from sqlalchemy.types import *
## Calculate max string lengths for object columns
key_len = basics['tconst'].fillna('').map(len).max()
title_len = basics['primaryTitle'].fillna('').map(len).max()

# %%
## Create a schema dictonary using Sqlalchemy datatype objects
df_schema = {
    "tconst": String(key_len+1), 
    "primaryTitle": Text(title_len+1),
    'startYear':Float(),
    'endYear':Float(),
    'runtimeMinutes':Integer()}

# %%
# Save to sql with dtype and index=False
basics.to_sql('title_basics',engine,dtype=df_schema,if_exists='replace',index=False)
# Out:
# 136208

# %%
engine.execute('ALTER TABLE title_basics ADD PRIMARY KEY (`tconst`);')

# %%
title_basics = basics

# %%
q = """SELECT * FROM title_basics LIMIT 5;"""
pd.read_sql(q, engine)
# Out:
#       tconst                                       primaryTitle  startYear  \
# 0  tt0035423                                     Kate & Leopold     2001.0
# 1  tt0062336  The Tango of the Widower and Its Distorting Mi...     2020.0
# 2  tt0069049                         The Other Side of the Wind     2018.0
# 3  tt0079644                                      November 1828     2001.0
# 4  tt0088751                                  The Naked Monster     2005.0
#
#   endYear  runtimeMinutes
# 0    None             118
# 1    None              70
# 2    None             122
# 3    None             140
# 4    None             100

# %%
title_ratings = pd.read_csv('Data/title_ratings.csv.gz', low_memory=False)
title_ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1909
# 1        tt0000002            5.8       256
# 2        tt0000003            6.5      1710
# 3        tt0000004            5.6       169
# 4        tt0000005            6.2      2525
# ...            ...            ...       ...
# 1258871  tt9916690            6.5         6
# 1258872  tt9916720            5.1       252
# 1258873  tt9916730            8.4         6
# 1258874  tt9916766            6.8        21
# 1258875  tt9916778            7.2        35
#
# [1258876 rows x 3 columns]

# %%
title_ratings.to_sql('title_ratings', engine, if_exists='replace',index=False)
# Out:
# 1258876

# %%
q = """SELECT * FROM title_ratings LIMIT 5;"""
pd.read_sql(q, engine)
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1909
# 1  tt0000002            5.8       256
# 2  tt0000003            6.5      1710
# 3  tt0000004            5.6       169
# 4  tt0000005            6.2      2525

# %%
tmdb = pd.read_csv('Data/df_2000_2001.csv.gz', low_memory=False)
tmdb.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0116748    0.0                               NaN                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN
# 2         0.0           [{'id': 878, 'name': 'Science Fiction'}]      NaN
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN
# 4         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN
#
#          id original_language   original_title  ... revenue  runtime  \
# 0       NaN               NaN              NaN  ...     NaN      NaN
# 1   62127.0                en  The Fantasticks  ...     0.0     86.0
# 2  110977.0                en    For the Cause  ...     0.0    100.0
# 3  442869.0                hi             Gang  ...     0.0    152.0
# 4  579396.0                hi         Karobaar  ...     0.0    180.0
#
#                                     spoken_languages    status  \
# 0                                                NaN       NaN
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 4  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
#
#                                          tagline            title  video  \
# 0                                            NaN              NaN    NaN
# 1  Try to remember the first time magic happened  The Fantasticks    0.0
# 2   The ultimate showdown on a forbidden planet.    For the Cause    0.0
# 3                                            NaN             Gang    0.0
# 4                           The Business of Love         Karobaar    0.0
#
#    vote_average vote_count certification
# 0           NaN        NaN           NaN
# 1           5.5       22.0           NaN
# 2           5.1        8.0           NaN
# 3           0.0        0.0           NaN
# 4           5.5        2.0           NaN
#
# [5 rows x 26 columns]

# %%
tmdb.drop(columns='adult',inplace=True)
tmdb.drop(columns='backdrop_path', inplace=True)
tmdb.drop(columns='belongs_to_collection', inplace=True)
tmdb.drop(columns='genres', inplace=True)
tmdb.drop(columns='homepage', inplace=True)
tmdb.drop(columns='id', inplace=True)
tmdb.drop(columns='original_language', inplace=True)
tmdb.drop(columns='overview', inplace=True)
tmdb.drop(columns='popularity', inplace=True)
tmdb.drop(columns='poster_path', inplace=True)
tmdb.drop(columns='production_companies', inplace=True)
tmdb.drop(columns='production_countries', inplace=True)
tmdb.drop(columns='release_date', inplace=True)
tmdb.drop(columns='runtime', inplace=True)
tmdb.drop(columns='spoken_languages', inplace=True)
tmdb.drop(columns='status', inplace=True)
tmdb.drop(columns='tagline', inplace=True)
tmdb.drop(columns='video', inplace=True)
tmdb.drop(columns='vote_average', inplace=True)
tmdb.drop(columns='vote_count', inplace=True)
tmdb.drop(columns='original_title', inplace=True)
tmdb.head()
# Out:
#      imdb_id      budget  revenue            title certification
# 0          0         NaN      NaN              NaN           NaN
# 1  tt0113026  10000000.0      0.0  The Fantasticks           NaN
# 2  tt0113092         0.0      0.0    For the Cause           NaN
# 3  tt0116391         0.0      0.0             Gang           NaN
# 4  tt0116748         0.0      0.0         Karobaar           NaN

# %%
tmdb.dropna(subset=['title'], inplace=True)
tmdb.isna().sum()
# Out:
# imdb_id             0
# budget              0
# revenue             0
# title               0
# certification    4229
# dtype: int64

# %%
tmdb.to_sql('tmdb', engine, if_exists='replace',index=False)
# Out:
# 5055

# %%
q = """SELECT * FROM tmdb LIMIT 5;"""
pd.read_sql(q, engine)
# Out:
#      imdb_id      budget     revenue                 title certification
# 0  tt0113026  10000000.0         0.0       The Fantasticks          None
# 1  tt0113092         0.0         0.0         For the Cause          None
# 2  tt0116391         0.0         0.0                  Gang          None
# 3  tt0116748         0.0         0.0              Karobaar          None
# 4  tt0118694    150000.0  12854953.0  In the Mood for Love            PG

# %%
q = """SHOW TABLES;"""
pd.read_sql(q, engine)
# Out:
#   Tables_in_movies
# 0           genres
# 1     title_basics
# 2     title_genres
# 3    title_ratings
# 4             tmdb

# %%
title_basics.to_csv("Data/final_basics_df.csv.gz",compression='gzip',index=False)

# %%
title_ratings.to_csv("Data/final_ratings_df.csv.gz",compression='gzip',index=False)

# %%
title_genres.to_csv("Data/final_genres_df.csv.gz",compression='gzip',index=False)

# %%
tmdb.to_csv("Data/final_tmdb_df.csv.gz",compression='gzip',index=False)
